# %%
import pandas as pd
import sqlite3 
import csv

# %%
df = pd.read_csv("PythonProject.csv", encoding_errors='ignore')
df.head().T
# Out:
# C:\Users\alan\AppData\Local\Temp\ipykernel_25472\2970362739.py:1: DtypeWarning: Columns (66,116,117) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("PythonProject.csv", encoding_errors='ignore')
#                          0               1               2               3  \
# eventid     201201000000.0  201201000000.0  201201000000.0  201201000000.0
# iyear                 2012            2012            2012            2012
# imonth                   1               1               1               1
# iday                     1               1               1               1
# approxdate             NaN             NaN             NaN             NaN
# ...                    ...             ...             ...             ...
# INT_LOG                 -9               1               0               1
# INT_IDEO                -9               1               0               1
# ...

# %%
pd.options.display.max_info_columns=200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52134 entries, 0 to 52133
# Data columns (total 137 columns):
#  #    Column              Non-Null Count  Dtype
# ---   ------              --------------  -----
#  0    eventid             52134 non-null  float64
#  1    iyear               52134 non-null  int64
#  2    imonth              52134 non-null  int64
#  3    iday                52134 non-null  int64
#  4    approxdate          4353 non-null   object
#  5    extended            52134 non-null  int64
#  6    resolution          1288 non-null   object
#  7    country             52134 non-null  int64
#  8    country_txt         52134 non-null  object
#  9    region              52134 non-null  int64
#  10   region_txt          52134 non-null  object
#  11   provstate           52134 non-null  object
#  12   city                52134 non-null  object
#  13   latitude            51789 non-null  float64
#  14   longitude           51789 non-null  float64
# ...

# %%
df_1 = df.loc[:100, ['iyear', 'country','country_txt','dbsource','INT_LOG']]

# %%
df_1
# Out:
#      iyear  country  country_txt                  dbsource  INT_LOG
# 0     2012      153     Pakistan  START Primary Collection       -9
# 1     2012      104        Kenya  START Primary Collection        1
# 2     2012      153     Pakistan  START Primary Collection        0
# 3     2012      104        Kenya  START Primary Collection        1
# 4     2012      153     Pakistan  START Primary Collection       -9
# ..     ...      ...          ...                       ...      ...
# 96    2012       92        India  START Primary Collection       -9
# 97    2012       95         Iraq  START Primary Collection       -9
# 98    2012       95         Iraq  START Primary Collection       -9
# 99    2012        4  Afghanistan  START Primary Collection        0
# 100   2012       92        India  START Primary Collection       -9
#
# [101 rows x 5 columns]

# %%
con = sqlite3.connect('../database/GlobalTerrorism.db')
cursor = con.cursor()

df_1.to_sql('data_terrorism', con, index=False) 

rows = cursor.execute("SELECT * FROM data_terrorism").fetchall()
print(rows)

con.commit()
con.close()
# Out:
# [(2012, 153, 'Pakistan', 'START Primary Collection', -9), (2012, 104, 'Kenya', 'START Primary Collection', 1), (2012, 153, 'Pakistan', 'START Primary Collection', 0), (2012, 104, 'Kenya', 'START Primary Collection', 1), (2012, 153, 'Pakistan', 'START Primary Collection', -9), (2012, 153, 'Pakistan', 'START Primary Collection', -9), (2012, 95, 'Iraq', 'START Primary Collection', -9), (2012, 4, 'Afghanistan', 'START Primary Collection', 0), (2012, 4, 'Afghanistan', 'START Primary Collection', -9), (2012, 153, 'Pakistan', 'START Primary Collection', -9), (2012, 229, 'Democratic Republic of the Congo', 'START Primary Collection', 1), (2012, 95, 'Iraq', 'START Primary Collection', -9), (2012, 153, 'Pakistan', 'START Primary Collection', -9), (2012, 95, 'Iraq', 'START Primary Collection', -9), (2012, 95, 'Iraq', 'START Primary Collection', -9), (2012, 92, 'India', 'START Primary Collection', -9), (2012, 217, 'United States', 'START Primary Collection', -9), (2012, 147, 'Nigeria', 'START Pr
# ...

# %%
rows[0]
# Out:
# (2012, 153, 'Pakistan', 'START Primary Collection', -9)
